# %%
from __future__ import print_function
import keras

from keras.datasets import imdb
from keras.models import load_model
from keras.preprocessing import sequence
from keras.models import Sequential
import os
import numpy as np

import pandas as pd
import random
import enum
# Out:
# Using TensorFlow backend.

# %%
PredictionMode = enum.Enum("PredictionMode", "cnn lstm fasttext cnn_lstm bidirectional_lstm")

# %%
'''
SWITCH PREDICTION MODE
'''
prediction_mode = PredictionMode.cnn
#prediction_mode = PredictionMode.lstm
#prediction_mode = PredictionMode.fasttext
#prediction_mode = PredictionMode.cnn_lstm
#prediction_mode = PredictionMode.bidirectional_lstm

max_features = 5000
maxlen = 400
model_filename = ''
INDEX_FROM=3   # word index offset

if prediction_mode == PredictionMode.cnn: 
    max_features = 5000
    maxlen = 400 
    model_filename = 'models/model_imdb_cnn.h5'
elif prediction_mode == PredictionMode.lstm: 
    max_features = 20000 
    maxlen = 80 
    model_filename = 'models/model_imdb_lstm.h5' 
elif prediction_mode == PredictionMode.fasttext: 
    max_features = 20000 
    maxlen = 400 
    model_filename = 'models/model_imdb_fasttext.h5' 
elif prediction_mode == PredictionMode.cnn_lstm: 
    max_features = 20000 
    maxlen = 100 
    model_filename = 'models/model_imdb_cnn_lstm.h5' 
elif prediction_mode == PredictionMode.bidirectional_lstm: 
    max_features = 20000 
    maxlen = 100 
    model_filename = 'models/model_imdb_bidirectional_lstm.h5'

print('Loading data...') 
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features, index_from=INDEX_FROM)

print(len(x_train), 'train sequences') 
print(len(x_test), 'test sequences') 
print('x_train shape:', x_train.shape) 
print('y_train shape:', y_train.shape) 
print('x_test shape:', x_test.shape) 
print('y_test shape:', y_test.shape)

print('Pad sequences (samples x time)') 
original_x_test = x_test

x_train = sequence.pad_sequences(x_train, maxlen=maxlen) 
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)

''' LOAD MODEL '''
model = load_model(model_filename)
# Out:
# Loading data...
# 25000 train sequences
# 25000 test sequences
# x_train shape: (25000,)
# y_train shape: (25000,)
# x_test shape: (25000,)
# y_test shape: (25000,)
# Pad sequences (samples x time)

# %%
# Make Word to ID dictionary
word_to_id = imdb.get_word_index()
word_to_id = {k:(v+INDEX_FROM) for k,v in word_to_id.items()}
word_to_id["[PAD]"] = 0
#word_to_id[""] = 0
word_to_id["[🏃]"] = 1 # START
word_to_id["[❓]"] = 2 # UNKNOWN

# Make ID to Word dictionary
id_to_word = {value:key for key,value in word_to_id.items()}

def restore_original_text(imdb_x_array):
    return (' '.join(id_to_word[id] for id in imdb_x_array ))

# %%
'''
PREDICT
'''
def imdb_class_to_str(imdb_class):
    if imdb_class == 0:
        return 'negative'
    return 'positive'

right = 0
mistake = 0

index_list = []
original_text_list = []
pred_prob_list = []
pred_class_list = []
y_test_list = []
fail_str_list = []

for i in range(100):
    index = random.randint(0, len(x_test))
    
    pred_prob = model.predict(x_test[index:(index+1)])[0][0] 
    pred_class = model.predict_classes(x_test[index:(index+1)])[0][0]
    
    '''
    print('pred_prod:', pred_prod)
    print('pred_class:', pred_class)
    print('y_test[index] :', y_test[index])
    '''
    fail_str = '' 
    
    if y_test[index] == pred_class:
        right += 1
    else:
        mistake += 1
        fail_str = 'Fail'
        
    original_text = restore_original_text(original_x_test[index])

    index_list.append(index)
    original_text_list.append(original_text)
    pred_prob_list.append(pred_prob)
    pred_class_list.append(imdb_class_to_str(pred_class))
    y_test_list.append(imdb_class_to_str(y_test[index]))
    fail_str_list.append(fail_str)

print(prediction_mode)
print("right : ", right)
print("mistake : ", mistake)
print("accuracy:", right/(right+mistake))

df = pd.DataFrame({'index': index_list, 
                   'x_train original_text': original_text_list, 
                   'probability': pred_prob_list, 
                   'pred_class': pred_class_list,
                   'y_test': y_test_list,
                   'is_fail': fail_str_list
                  })

df[['index', 'x_train original_text','probability','pred_class','y_test','is_fail']]
# Out:
# PredictionMode.cnn
# right :  86
# mistake :  14
# accuracy: 0.86
#     index                              x_train original_text  probability  \
# 0   10606  [🏃] since i am not a big steven seagal fan i t...     0.032832
# 1   10466  [🏃] one dark night is a [❓] in the [❓] low bud...     0.959998
# 2     371  [🏃] another great tom [❓] performance [❓] sepa...     0.843495
# 3   23193  [🏃] i am so disappointed in this movie i can't...     0.053851
# 4   19655  [🏃] when i first saw this show i was 9 and it ...     0.974339
# 5    1384  [🏃] this may not be [❓] as a review on any fil...     0.040330
# 6    9061  [🏃] it's hard to imagine in this day and age h...     0.760508
# 7   12961  [🏃] from the brilliant mind that brought us th...     0.021393
# 8   23342  [🏃] this movie cannot be serious because it ha...     0.000289
# 9   20873  [🏃] so one day i was in the video store lookin...     0.001086
# 10  16702  [🏃] burt [❓] and [❓] in this great cop film [❓...     0.483076
# 11   4376  [🏃] the last dinosaur was one of those out of ...     0.346612
# 12  20768  [🏃] this movie was amazing i was in tears by t...     0.944461
# 13    398  [🏃] i bought this dvd from [❓] for cheap think...     0.969885
# 14   8880  [🏃] this movie [❓] something most other movies...     0.625466
# 15   8783  [🏃] as anthony said i wanted to stick my head ...     0.000191
# 16   6635  [🏃] ok chuck [❓] has shown up in many an enter...     0.065776
# 17  20714  [🏃] maybe you have to be a former hippie to fu...     0.000838
# 18  16122  [🏃] i have not seen and heard the original ver...     0.016674
# 19   5018  [🏃] feels like an [❓] film if there is such a ...     0.972986
# 20   2019  [🏃] this film made me so angry because of its ...     0.005343
# 21   8338  [🏃] [❓] loves his only he'd love her better si...     0.791030
# 22  19156  [🏃] i must have been around ten years old when...     0.636000
# 23   9497  [🏃] if i could rate it a zero i would coming f...     0.001099
# 24  18809  [🏃] clint howard brother of more talented ron ...     0.004429
# 25   9583  [🏃] this is per [❓] an above average film but ...     0.005798
# 26  10199  [🏃] the plot involves a new [❓] franchise [❓] ...     0.067615
# 27   9132  [🏃] [❓] is another day is not the sequel to go...     0.350507
# 28   9710  [🏃] cuba [❓] jr and ed harris are touching thi...     0.951614
# 29   8463  [🏃] we just saw this movie in [❓] texas at the...     0.858546
# ..    ...                                                ...          ...
# 70  15341  [🏃] another hand held horror means another [❓]...     0.214579
# 71   3591  [🏃] i first saw this as a kid the little [❓] f...     0.448800
# 72    542  [🏃] this 8 minute gem is not only timeless but...     0.992204
# 73   6806  [🏃] i remember catching this movie on one of t...     0.321714
# 74  13228  [🏃] i have watched [❓] from first episode to n...     0.989564
# 75  18244  [🏃] a modern scare film [❓] it is br br the [❓...     0.144496
# 76   2612  [🏃] it actually [❓] me to say it but this movi...     0.002021
# 77   6501  [🏃] as far as fake documentaries go anyone thi...     0.464712
# 78   4746  [🏃] [❓] scott does what he does best i e plays...     0.614056
# 79  20426  [🏃] this is another notorious mexican horror f...     0.609815
# 80  12506  [🏃] remember back when this movie was made by ...     0.995255
# 81  20941  [🏃] this is a prime example of [❓] [❓] at its ...     0.799772
# 82   6699  [🏃] this has got to be the funniest movie i ha...     0.759316
# 83  16111  [🏃] the odd mixture of comedy and horror somet...     0.821335
# 84  11799  [🏃] [❓] [❓] is where the sequel [❓] of the [❓]...     0.012494
# 85   7432  [🏃] pretty [❓] good looking cast the story [❓]...     0.034115
# 86  17735  [🏃] strong [❓] and it clearly shows government...     0.650083
# 87  13640  [🏃] nothing dull about this movie which is hel...     0.137810
# 88  10862  [🏃] [❓] intense and [❓] is a documentary like ...     0.131923
# 89    854  [🏃] most critics have written [❓] about that m...     0.116712
# 90   2507  [🏃] this is truly a documentary of love about ...     0.997620
# 91   6581  [🏃] if you like madonna or not this movie is h...     0.870057
# 92  14488  [🏃] essential viewing for anyone who watches t...     0.985214
# 93   8473  [🏃] i love [❓] terrific characters and poignan...     0.910778
# 94   8394  [🏃] it's painfully obvious that the people who...     0.001130
# 95  13822  [🏃] you might think that a show about regular ...     0.015575
# 96    427  [🏃] it has taken me about a year now after see...     0.672148
# 97    482  [🏃] the world is going to miss john [❓] this w...     0.757354
# 98    288  [🏃] there is something about true stories that...     0.980066
# 99   8323  [🏃] blade was a thrilling horror masterpiece a...     0.986180
#
#    pred_class    y_test is_fail
# 0    negative  negative
# 1    positive  positive
# 2    positive  positive
# 3    negative  negative
# 4    positive  positive
# 5    negative  positive    Fail
# 6    positive  positive
# 7    negative  negative
# 8    negative  negative
# 9    negative  negative
# 10   negative  positive    Fail
# 11   negative  positive    Fail
# 12   positive  positive
# 13   positive  positive
# 14   positive  positive
# 15   negative  negative
# 16   negative  negative
# 17   negative  negative
# 18   negative  negative
# 19   positive  positive
# 20   negative  negative
# 21   positive  positive
# 22   positive  positive
# 23   negative  negative
# 24   negative  negative
# 25   negative  negative
# 26   negative  negative
# 27   negative  positive    Fail
# 28   positive  positive
# 29   positive  positive
# ..        ...       ...     ...
# 70   negative  positive    Fail
# 71   negative  positive    Fail
# 72   positive  positive
# 73   negative  negative
# 74   positive  positive
# 75   negative  negative
# 76   negative  negative
# 77   negative  positive    Fail
# 78   positive  positive
# 79   positive  negative    Fail
# 80   positive  positive
# 81   positive  positive
# 82   positive  positive
# 83   positive  negative    Fail
# 84   negative  negative
# 85   negative  negative
# 86   positive  positive
# 87   negative  positive    Fail
# 88   negative  negative
# 89   negative  negative
# 90   positive  positive
# 91   positive  positive
# 92   positive  positive
# 93   positive  positive
# 94   negative  negative
# 95   negative  negative
# 96   positive  positive
# 97   positive  positive
# 98   positive  positive
# 99   positive  positive
#
# [100 rows x 6 columns]
